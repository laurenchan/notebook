# %%
getwd()
# Out:
# [1] "/Users/chan5416/Documents/GitHub/notebook/microbes"

# %%
library(ggplot2)
library(dplyr)
library("viridis") 
library(ggsci)
library(wesanderson)

# %%
dat <- read.delim("data.txt", header=TRUE, sep="\t")

# %%
dat <- as.data.frame(dat)

# %%
names(dat)
# Out:
# [1] "Class"    "Order"    "sampling"

# %%
dat$sampling <- factor(dat$sampling, levels=c("Frog", "PF","DN"))

# %%
summarizemydata<-dat %>% group_by(sampling, Class, Order) %>% tally
head(summarizemydata)
# Out:
#   sampling Class     Order       n
# 1 Frog     Arachnida Araneae     12
# 2 Frog     Chordata  Vertebrata   4
# 3 Frog     Insecta   Coleoptera  50
# 4 Frog     Insecta   Diptera      5
# 5 Frog     Insecta   Hemiptera    5
# 6 Frog     Insecta   Hymenoptera 22

# %% [markdown]
# ### Rearranged data in excel then import

# %%
mysum <- read.delim("summary.txt", header=T, sep="\t")
mysum <- as.data.frame(mysum)

mysum2 <- read.delim("summary2.txt", header=T, sep="\t")
mysum2 <- as.data.frame(mysum2)

# %%
mysum2$Sample <- factor(mysum2$Sample, levels=c("Prey", "Total", "Pitfall", "Dipnet"))
mysum2$Taxon <- factor(mysum2$Taxon, levels=c("Coleoptera ",
"Collembola ",
"Diptera ",
"Hemiptera ",
"Hymenoptera",
"Lepidoptera",
"Odonata ",
"Orthoptera",
"Unknown Hexapoda",
"Arachnida",
"Myriapoda",
"Nematoda ",
"Annelida",
"Gastropoda ",
"Crustacea",
"Vertebrata "))

# %%
myplot2 <- ggplot(data=mysum2, aes(x="", y=Percent, group=Taxon, color=Taxon, fill=Taxon)) +
    geom_bar(width=1, stat="identity") +
    coord_polar("y", start=0) +
    facet_wrap(~ Sample) +
    theme(axis.text = element_blank(), 
          axis.ticks = element_blank(),
          panel.grid  = element_blank()) +
    scale_color_viridis(discrete = TRUE, option = "D")+
    scale_fill_viridis(discrete = TRUE)

# %%
myplot2
# Out:
# plot without title

# %%
mycol<-rainbow(16)

# %%
myplot3 <- ggplot(data=mysum2, aes(x="", y=Percent, group=Taxon, color=Taxon, fill=Taxon)) +
    geom_bar(width=1, stat="identity", color="gray", cex=0.1) +
    coord_polar("y", start=0) +
    facet_wrap(~ Sample) +
    theme(axis.text = element_blank(), 
          axis.ticks = element_blank(),
          panel.grid  = element_blank()) +
    scale_fill_manual(values=mycol)

# %%
myplot3
# Out:
# plot without title
